# %% [markdown]
# <a href="https://colab.research.google.com/github/diegomezapy/Big-Data-Intro/blob/diego/ejemplo_EPH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datos Encuesta de Hogares

# %%
# cargar la base EPH 2024
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

eph=pd.read_csv("/content/drive/MyDrive/EPHn/REG02_EPHC_ANUAL_2024.csv", delimiter=";")
# Out:
# <ipython-input-8-197491152>:8: DtypeWarning: Columns (197,199,202,206,207,208,209,210,211) have mixed types. Specify dtype option on import or set low_memory=False.
#   eph=pd.read_csv("/content/drive/MyDrive/EPHn/REG02_EPHC_ANUAL_2024.csv", delimiter=";")
# Index(['UPM', 'NVIVI', 'NHOGA', 'AÑO', 'DPTO', 'AREA', 'L02', 'P02', 'P03',
#        'P04',
#        ...
#        'ingrevasode', 'ingrealmuerzode', 'ipcm', 'pobrezai', 'pobnopoi',
#        'quintili', 'decili', 'quintiai', 'decilai', 'informalidad'],
#       dtype='object', length=213)

# %%
eph.columns
# Out:
# Index(['UPM', 'NVIVI', 'NHOGA', 'AÑO', 'DPTO', 'AREA', 'L02', 'P02', 'P03',
#        'P04',
#        ...
#        'ingrevasode', 'ingrealmuerzode', 'ipcm', 'pobrezai', 'pobnopoi',
#        'quintili', 'decili', 'quintiai', 'decilai', 'informalidad'],
#       dtype='object', length=213)

# %%
# salario promedio de trabajadores privados

t1=eph["P02"].value_counts()
print(t1)
# Out:
# P02
# 10     1086
# 9      1080
# 7      1058
# 8      1054
# 13     1047
#        ...
# 100       3
# 101       3
# 103       1
# 99        1
# 106       1
# Name: count, Length: 105, dtype: int64

# %%
pd.crosstab(eph["P02"],eph["P06"])
# Out:
# P06    1    6
# P02
# 0    310  356
# 1    393  418
# 2    463  403
# 3    481  474
# 4    513  450
# ..   ...  ...
# 100    1    2
# 101    1    2
# 102    1    2
# 103    0    1
# 106    0    1
#
# [105 rows x 2 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
pd.crosstab(eph["P02"],eph["P06"])
# Out:
# P06    1    6
# P02
# 0    310  356
# 1    393  418
# 2    463  403
# 3    481  474
# 4    513  450
# ..   ...  ...
# 100    1    2
# 101    1    2
# 102    1    2
# 103    0    1
# 106    0    1
#
# [105 rows x 2 columns]
